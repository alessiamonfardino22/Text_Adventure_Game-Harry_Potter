# %%
"""
DocString:

This game is based on the first Harry Potter book, "Harry Potter and the Philosopher's Stone". The game will end with 
the wizard and his friends defeating Lord Voldemort and saving the stone, or with the stone falling into the wrong ends
and the beginning of a dark phase for Hogwarts. 
This game requires knowledge of the Harry Potter universe, and a sense of adventure and problem-solving skills!

First Part: Decide whether or not to sneak into Hogwarts' forbidden hallways.
Second Part: Navigate the traps in the Philosopher's Stone chamber.
Third Part: Defeat Lord Voldemort.

"""

# Import the exit function to end the game when the user selectes the wrong choice 

from sys import exit

# Define a list that can be called everytime we want to mention Harry's friends

friends = ["Ron", "Hermione"]

# Create a user defined function with the starting scenario and create a loop with a while statement.
# In every user defined function, control for errors with try and except. 

def start():

    while True:
        try:
            print("You and your friends are on a mission to find the Philosopher's Stone. \
\nThe stone is said to have the power to grant immortality to whoever finds it \
\nand you heard that Voldemort is looking for it. \
\nAre you ready to sneak into\nHogwarts and embark on this dangerous quest? ")
            input("<Press enter to start the adventure>\n")
            starting_path() 
            
        except Exception as e:
            print(f"Error: {e}")
            exit(0)

# Create a user defined function with the first scenario and create a loop with a while statement.
# Ask the user to make their first choice, and proceed by connecting the nested conditionals to other sections of the game.
# Allow the user to input different similar options. If they don't, ask to input again with the else statement.
# When the user selects the wrong option, print 'Game Over' and exit the game through the exit() function

def starting_path():

    while True:
        try:
            print("As the leader of the group, what would you like to do? \
\n1) sneaking into Hogward's forbidden hallways \
\n2) give up hoping that the spells will keep it hidden forever ")    
            choice = input(">  \n").lower()
           

            if "1" in choice or "sneak" in choice or "Hogwarts" in choice:
                print("You and your friends, "+ ' and '.join(friends) + ',' + " start sneaking into Hogwarts!")
                input("<Press enter to continue the adventure>\n")
                hogwarts_area()

            elif "2" in choice or "give up" in choice or "quest" in choice:
                print("You are afraid that a professor will see you and disqualify you from the triwizard tournament. \
\nThe adventure is over, but you have the honor of having protected your friends from unknown dangers! \
\nThe stone falls into the wrong hands and the wizarding world is plunged into darkness. \
\nStart your training, this is the beginning of a series of battles!")
                print('Game Over! Thank you for playing')
                exit(0)

            else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue the adventure>\n")
                starting_path()

        except Exception as e:
            print(f"Error: {e}")
            exit(0)  

# Repeat the previous steps             
def hogwarts_area():

    while True:
        try:
            print("As you and your friends sneak into Hogwarts, you find a secret passage \
that leads to the chamber where the\nPhilosopher's Stone is hidden. \
However, the chamber is protected by a series of traps and spells. \
\nWhat would you like to do? \
\n1) try to trick the traps and cast powerful spells \
\n2) try to find another way")
                      
            choice = input(">  \n").lower()

            if "1" in choice or "trick" in choice or "traps" in choice or "spells" in choice or "cast" in choice:
                print("You and Ron try to avoid the traps, while Hermione shows off \
her knowledge in dark magic spells.")
                input("<Press enter to continue>\n")
                challenges_area()

            elif "2" in choice or "find" in choice or "another way" in choice:
                print("You and your friends try to find another way to reach the Philosopher's Stone.") 
                input("<Press enter to continue>\n")
                another_way()

            else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue the adventure>\n")
                exit(0)
            
        except Exception as e:
            print(f"Error: {e}")
            exit(0)           
        
# Repeat the previous steps  

def another_way():
    
    while True:   
        try:
            print("After searching for a while, you and your friends find a secret passage that leads to the chamber \
\nwhere the Philosopher's Stone is hidden. \
\nHowever, the passage is guarded by terrifying magical creature. \
\nWhat would you like to do? \
\n1) try to defeat the creature \
\n2) try to find another way \
\n3) give up hoping that the spells will keep it hidden forever")
            
            choice = input(">  \n").lower()
            

            if "1" in choice or "defeat" in choice or "creature" in choice:
                print("You and your friends use your best magic spells and successfully defeat the creature!")
                input("<Press enter to continue>\n")
                challenges_area()

            elif "2" in choice or "find" in choice or "another way" in choice:
                print("You and your friends keep searching for another way to reach the Philosopher's Stone.")
                input("<Press enter to continue>\n")
                another_way()

            elif "3" in choice or "give up" in choice or "quest" in choice:
                print("You are afraid that a professor will see you and disqualify you from the triwizard tournament. \
\nThe adventure is over, but you have the honor of having protected your friends from unknown dangers!")
                print('Game Over! Thank you for playing.')
                exit(0)

            else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue the adventure>\n")
                another_way()

        except Exception as e:
            print(f"Error: {e}")
            exit(0)           
        
# Repeat the previous steps  

def challenges_area():
    
    while True:   
        try:

            print("You and your friends successfully navigate the traps in the chamber and reach the Philosopher's Stone. \
\nYou realize that Lord Voldemort is also after the stone. \
\nWhat would you like to do? \
\n1) try to defeat Lord Voldemort. \
\n2) try to escape with the stone. \
\n3) hide, Lord Voldemort is too powerful and you do not want to put your friends in danger.")
            
            choice = input(">  \n").lower()

            if "1" in choice or "defeat" in choice or "Voldemort" in choice:
                print("You and your friends use your magic spells and successfully defeat Lord Voldemort! \
\nWith the stone in your possession, you can now use its power for good and make a difference in the wizarding world.\
\nThe adventure may be over, but the journey has just begun!")
                print('Thank you for playing!')
                exit(0)

            elif "2" in choice or "escape" in choice or "stone" in choice:
                print("You and your friends try to escape with the Philosopher's Stone.")
                input("<Press enter to continue>\n")
                escape()

            elif "3" in choice or "hide" in choice or "danger" in choice or "run away" in choice:
                print("A magician knows when it is time to step aside. \
\nThe stone falls into the wrong hands and the wizarding world is plunged into darkness.\
\nThe magical world is in danger and it needs you! \
\nBegin your training, this is the beginning of a series of battles.")
                print('Game Over! Thank you for playing')
                exit(0)

            else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue the adventure>\n")
                challenges_area()

        except Exception as e:
            print(f"Error: {e}")
            exit(0)           

# Repeat the previous steps              

def escape():
    while True:    
        try:

            print("You and your friends make a run for it with the Philosopher's Stone. \
\nHowever, Lord Voldemort and his followers catch up to you.\
\nWhat would you like to do?\
\n1) fight them off.\
\n2) surrender the stone.")
            
            choice = input(">  \n").lower()

            if "1" in choice or "fight" in choice or "them off" in choice:
                print("You and your friends use your magic spells and try to fight off Lord Voldemort and his followers.")
                input("<Press enter to continue>\n")
                print("The stone falls into the wrong hands and the wizarding world is plunged into darkness.\
\nThe magical world is in danger and it needs you! \
\nBegin your training, this is the beginning of a series of battles. \
\nGame Over! Thank you for playing.")
                exit()
 

            elif "2" in choice or "surrender" in choice or "stone" in choice:
                print("You and your friends reluctantly surrender the Philosopher's Stone to Lord Voldemort.")
                input("<Press enter to continue>\n")
                print("The stone falls into the wrong hands and the wizarding \
world is plunged into darkness. The magical world is in danger and it needs you! \
Begin your training, this is the beginning of a series of battles. \
Game Over! Thank you for playing.")
                exit()     

            else:
                print("Invalid command. Please try again.")
                input("<Press enter to continue the adventure>\n")
                escape()

        except Exception as e:
            print(f"Error: {e}")
            exit(0)         

# Call the start function 
    
start()
# Out:
# You and your friends are on a mission to find the Philosopher's Stone.
# The stone is said to have the power to grant immortality to whoever finds it
# and you heard that Voldemort is looking for it.
# Are you ready to sneak into
# Hogwarts and embark on this dangerous quest?
# <Press enter to start the adventure>
#
# As the leader of the group, what would you like to do?
# 1) sneaking into Hogward's forbidden hallways
# 2) give up hoping that the spells will keep it hidden forever
# >
# 1
# You and your friends, Ron and Hermione, start sneaking into Hogwarts!
# <Press enter to continue the adventure>
#
# As you and your friends sneak into Hogwarts, you find a secret passage that leads to the chamber where the
# Philosopher's Stone is hidden. However, the chamber is protected by a series of traps and spells.
# What would you like to do?
# 1) try to trick the traps and cast powerful spells
# 2) try to find another way
# >
# 1
# ...
